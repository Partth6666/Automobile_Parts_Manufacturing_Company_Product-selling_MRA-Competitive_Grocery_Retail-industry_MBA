# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import zscore                                        # ZSCORE SCALING
from sklearn.preprocessing import StandardScaler                 # ZScore

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, centroid          # HIERARCHICAL CLUSTERING 
from sklearn.cluster import KMeans                                    # K-MEANS CLUSTERING

from sklearn.metrics import silhouette_samples, silhouette_score      # SILHOUETTE SCORE FOR K-MEANS

from statsmodels.tsa.seasonal import seasonal_decompose


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set(color_codes=True)
sns.set_palette('Accent_r')

# %config InlineBackend.figure_format ='retina'

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

plt.rcParams['figure.figsize'] = 16, 9

# %%
df = pd.read_csv('dataset_group.csv')
df.head(10).to_csv('df_head.csv')
df.head(10)
# Out:
#          Date  Order_id        Product
# 0  01-01-2018         1         yogurt
# 1  01-01-2018         1           pork
# 2  01-01-2018         1  sandwich bags
# 3  01-01-2018         1     lunch meat
# 4  01-01-2018         1   all- purpose
# 5  01-01-2018         1          flour
# 6  01-01-2018         1           soda
# 7  01-01-2018         1         butter
# 8  01-01-2018         1           beef
# 9  01-01-2018         1  aluminum foil

# %%
df.shape
# Out:
# (20641, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  object
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 483.9+ KB

# %%
df.describe().T.to_csv('describe_num.csv');
df.describe(include='object').T.to_csv('describe_cat.csv');

df.describe(include='object').T
df.describe().T
# Out:
#          count unique         top freq
# Date     20641    603  08-02-2019  183
# Product  20641     37     poultry  640
#             count        mean         std  min    25%    50%    75%     max
# Order_id  20641.0  575.986289  328.557078  1.0  292.0  581.0  862.0  1139.0

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  datetime64[ns]
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 483.9+ KB

# %%
df.describe().T.to_csv('describe_num.csv');
df.describe(include='object').T.to_csv('describe_cat.csv');

df.describe(include='object').T
df.describe().T
# Out:
#          count unique      top freq
# Product  20641     37  poultry  640
#             count                           mean                  min  \
# Date        20641  2018-12-21 14:03:01.735381248  2018-01-01 00:00:00
# Order_id  20641.0                     575.986289                  1.0
#
#                           25%                  50%                  75%  \
# Date      2018-05-29 00:00:00  2019-01-30 00:00:00  2019-06-20 00:00:00
# Order_id                292.0                581.0                862.0
#
#                           max         std
# Date      2020-02-26 00:00:00         NaN
# Order_id               1139.0  328.557078

# %%
df_datesplit = df.copy()

# %%
df_datesplit['YEAR'] = pd.PeriodIndex(df_datesplit['Date'], freq='Y')
df_datesplit['MONTH'] = pd.PeriodIndex(df_datesplit['Date'], freq='M')
df_datesplit['QUARTER'] = pd.PeriodIndex(df_datesplit['Date'], freq='Q')
df_datesplit['WEEK'] = pd.PeriodIndex(df_datesplit['Date'], freq='W')

# %%
df_datesplit['DAY'] = df_datesplit.Date.dt.strftime('%A')
df_datesplit['MONTH_NAME'] = df_datesplit['Date'].dt.strftime('%b')

# %%
df_datesplit.head()

df_datesplit.tail()
# Out:
#         Date  Order_id        Product  YEAR    MONTH QUARTER  \
# 0 2018-01-01         1         yogurt  2018  2018-01  2018Q1
# 1 2018-01-01         1           pork  2018  2018-01  2018Q1
# 2 2018-01-01         1  sandwich bags  2018  2018-01  2018Q1
# 3 2018-01-01         1     lunch meat  2018  2018-01  2018Q1
# 4 2018-01-01         1   all- purpose  2018  2018-01  2018Q1
#
#                     WEEK     DAY MONTH_NAME
# 20629 2020-02-25      1138                         sugar  2020  2020-02
# 20630 2020-02-25      1138               spaghetti sauce  2020  2020-02
# 20631 2020-02-25      1138                  all- purpose  2020  2020-02
# 20632 2020-02-25      1138                 sandwich bags  2020  2020-02
# 20633 2020-02-25      1138                  toilet paper  2020  2020-02
# 20634 2020-02-25      1138                          soda  2020  2020-02
# 20635 2020-02-25      1138                          soda  2020  2020-02
# 20636 2020-02-25      1138                          soda  2020  2020-02
# 20637 2020-02-25      1138                  paper towels  2020  2020-02
# 20638 2020-02-26      1139                          soda  2020  2020-02
# 20639 2020-02-26      1139             laundry detergent  2020  2020-02
# 20640 2020-02-26      1139                       shampoo  2020  2020-02
#
#       QUARTER                   WEEK        DAY MONTH_NAME
# 20591  2020Q1  2020-02-17/2020-02-23     Sunday        Feb
# 20592  2020Q1  2020-02-17/2020-02-23     Sunday        Feb
# 20593  2020Q1  2020-02-17/2020-02-23     Sunday        Feb
# 20594  2020Q1  2020-02-17/2020-02-23     Sunday        Feb
# 20595  2020Q1  2020-02-17/2020-02-23     Sunday        Feb
# 20596  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20597  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20598  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20599  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20600  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20601  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20602  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20603  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20604  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20605  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20606  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20607  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20608  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20609  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20610  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20611  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20612  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20613  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20614  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20615  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20616  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20617  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20618  2020Q1  2020-02-24/2020-03-01     Monday        Feb
# 20619  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20620  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20621  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20622  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20623  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20624  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20625  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20626  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20627  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20628  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20629  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20630  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20631  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20632  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20633  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20634  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20635  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20636  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20637  2020Q1  2020-02-24/2020-03-01    Tuesday        Feb
# 20638  2020Q1  2020-02-24/2020-03-01  Wednesday        Feb
# 20639  2020Q1  2020-02-24/2020-03-01  Wednesday        Feb
# 20640  2020Q1  2020-02-24/2020-03-01  Wednesday        Feb

# %%
print('First date of Sales data = ', min(df_datesplit['Date']))
print('Last date of Sales data = ', max(df_datesplit['Date']))
# Out:
# First date of Sales data =  2018-01-01 00:00:00
# Last date of Sales data =  2020-02-26 00:00:00

# %% [markdown]
# ### Time Series - YEARLY

# %%
df3 = df_datesplit.copy()
df_yr = pd.DataFrame(df3[['YEAR', 'Order_id', 'Product']].groupby('YEAR').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_yr.rename(columns=newname, inplace=True)
df_yr
# Out:
#       Num_of_Orders  Num_of_Products
# YEAR
# 2018            533             9479
# 2019            507             9333
# 2020             99             1829

# %%
df_yr['Num_of_Orders'].plot(color='blue');
plt.ylabel('No. of Orders');
plt.title('YEARLY ORDERS', fontsize=17)
plt.savefig('ts_YEAR_order.jpg', bbox_inches='tight');

# %%
df_yr['Num_of_Products'].plot(color='red');
plt.ylabel('No. of Products');
plt.title('YEARLY PRODUCTS SOLD', fontsize=17)
plt.savefig('ts_YEAR_prod.jpg', bbox_inches='tight');

# %% [markdown]
# ### Time Series - QUARTERLY

# %%
df3 = df_datesplit.copy()
df_qtr = pd.DataFrame(df3[['QUARTER', 'Order_id', 'Product']].groupby('QUARTER').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_qtr.rename(columns=newname, inplace=True)
df_qtr
# Out:
#          Num_of_Orders  Num_of_Products
# QUARTER
# 2018Q1             175             3114
# 2018Q2             178             3047
# 2018Q3             180             3318
# 2019Q1             180             3354
# 2019Q2             170             3054
# 2019Q3             157             2925
# 2020Q1              99             1829

# %%
df_qtr['Num_of_Orders'].plot(color='blue');
plt.ylabel('No. of Orders');
plt.title('QUARTERLY ORDERS', fontsize=17)
plt.savefig('ts_qtr_order.jpg', bbox_inches='tight');

# %%
df_qtr['Num_of_Products'].plot(color='red');
plt.ylabel('No. of Products');
plt.title('QUARTERLY PRODUCTS SOLD', fontsize=17)
plt.savefig('ts_qtr_prod.jpg', bbox_inches='tight');

# %% [markdown]
# ### Time Series - MONTHLY

# %%
df3 = df_datesplit.copy()
df_month = pd.DataFrame(df3[['MONTH', 'Order_id', 'Product']].groupby('MONTH').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_month.rename(columns=newname, inplace=True)
df_month
# Out:
#          Num_of_Orders  Num_of_Products
# MONTH
# 2018-01             62             1170
# 2018-02             55              907
# 2018-03             58             1037
# 2018-04             55              962
# 2018-05             67             1155
# 2018-06             56              930
# 2018-07             62             1054
# 2018-08             59             1159
# 2018-09             59             1105
# 2019-01             51              919
# 2019-02             63             1217
# 2019-03             66             1218
# 2019-04             55              975
# 2019-05             66             1182
# 2019-06             49              897
# 2019-07             53              943
# 2019-08             48              961
# 2019-09             56             1021
# 2020-01             61             1138
# 2020-02             38              691

# %%
df_month['Num_of_Products'].plot(color='red');
plt.ylabel('No. of Products');
plt.title('MONTHLY PRODUCTS SOLD', fontsize=17)
plt.savefig('ts_month_prod.jpg', bbox_inches='tight');

# %%
df_month['Num_of_Orders'].plot(color='blue');
plt.ylabel('No. of Orders');
plt.title('MONTHLY ORDERS', fontsize=17)
plt.savefig('ts_month_orders.jpg', bbox_inches='tight');

# %% [markdown]
# ### Time Series - WEEKLY

# %%
df3 = df_datesplit.copy()
df_week = pd.DataFrame(df3[['WEEK', 'Order_id', 'Product']].groupby('WEEK').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_week.rename(columns=newname, inplace=True)
df_week
# Out:
#                        Num_of_Orders  Num_of_Products
# WEEK
# 2018-01-01/2018-01-07             15              285
# 2018-01-08/2018-01-14             15              247
# 2018-01-15/2018-01-21             17              350
# 2018-01-22/2018-01-28              8              151
# 2018-01-29/2018-02-04             17              304
# ...                              ...              ...
# 2020-01-27/2020-02-02             10              204
# 2020-02-03/2020-02-09             13              202
# 2020-02-10/2020-02-16             10              183
# 2020-02-17/2020-02-23             10              213
# 2020-02-24/2020-03-01              3               45
#
# [88 rows x 2 columns]

# %%
df_week['Num_of_Orders'].mean()
df_week['Num_of_Orders'].median()
# Out:
# 12.943181818181818
# 13.0

# %%
df_week['Num_of_Products'].mean()
df_week['Num_of_Products'].median()
# Out:
# 234.5568181818182
# 232.0

# %%
df_week['Num_of_Orders'].plot(color='blue');
plt.ylabel('No. of Orders');
plt.title('WEEKLY ORDERS', fontsize=17)
plt.savefig('ts_week_orders.jpg', bbox_inches='tight');

# %%
df_week['Num_of_Products'].plot(color='red');
plt.ylabel('Count of No. of Product');
plt.title('WEEKLY PRODUCTS SOLD', fontsize=17)
plt.savefig('ts_week_product.jpg', bbox_inches='tight');

# %%
df['Product'].value_counts()
# Out:
# Product
# poultry                         640
# soda                            597
# cereals                         591
# ice cream                       579
# cheeses                         578
# waffles                         575
# soap                            574
# bagels                          573
# lunch meat                      573
# juice                           570
# eggs                            570
# toilet paper                    569
# dinner rolls                    567
# aluminum foil                   566
# coffee/tea                      565
# shampoo                         562
# beef                            561
# paper towels                    556
# flour                           555
# butter                          555
# milk                            555
# mixes                           554
# dishwashing liquid/detergent    551
# all- purpose                    551
# ketchup                         548
# yogurt                          545
# individual meals                544
# tortillas                       543
# pasta                           542
# laundry detergent               542
# spaghetti sauce                 536
# sandwich bags                   536
# sugar                           533
# pork                            531
# fruits                          529
# sandwich loaves                 523
# hand soap                       502
# Name: count, dtype: int64

# %%
df['Product'].value_counts().plot(kind='bar');
plt.savefig('prod_bar.jpg', bbox_inches='tight');

# %%
df3 = df_datesplit.copy()
df_day = pd.DataFrame(df3[['DAY', 'Order_id', 'Product']].groupby('DAY').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_day.rename(columns=newname, inplace=True)
df_day
# Out:
#            Num_of_Orders  Num_of_Products
# DAY
# Friday               167             3044
# Monday               143             2600
# Saturday             169             2988
# Sunday               169             3109
# Thursday             167             2969
# Tuesday              157             2943
# Wednesday            167             2988

# %%
sns.barplot(x=df_day.index.sort_values(ascending=True), y=df_day['Num_of_Orders'], order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']);
plt.title('TRANSACTIONS PER DAY OF WEEK', fontsize=17);
plt.savefig('week_bar.jpg', bbox_inches='tight');

# %%
sns.barplot(x=df_day.index.sort_values(ascending=True), y=df_day['Num_of_Products'], order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']);

# %%
df3 = df_datesplit.copy()
df_monthname = pd.DataFrame(df3[['MONTH_NAME', 'Order_id', 'Product']].groupby('MONTH_NAME').agg({'Order_id': 'nunique',
                                                                  'Product': 'count'}))
newname = {'Order_id': 'Num_of_Orders', 'Product': 'Num_of_Products'}
df_monthname.rename(columns=newname, inplace=True)
df_monthname
# Out:
#             Num_of_Orders  Num_of_Products
# MONTH_NAME
# Apr                   110             1937
# Aug                   107             2120
# Feb                   156             2815
# Jan                   174             3227
# Jul                   115             1997
# Jun                   105             1827
# Mar                   124             2255
# May                   133             2337
# Sep                   115             2126

# %%
sns.barplot(x=df_monthname.index, y=df_monthname['Num_of_Orders'], order=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.savefig('monthwise_orders.jpg', bbox_inches='tight');

# %%
df.head()
# Out:
#         Date  Order_id        Product
# 0 2018-01-01         1         yogurt
# 1 2018-01-01         1           pork
# 2 2018-01-01         1  sandwich bags
# 3 2018-01-01         1     lunch meat
# 4 2018-01-01         1   all- purpose

# %%
df_grpbydate = pd.DataFrame(df.groupby('Date').agg({'Order_id': 'nunique', 'Product': 'count'}))
df_grpbydate.head()
print('Total Num of Orders (Invoices) =', sum(df_grpbydate['Order_id']))
print('Total Num of Products  =', sum(df_grpbydate['Product']))
# Out:
#             Order_id  Product
# Date
# 2018-01-01         2       39
# 2018-01-02         4       80
# 2018-01-03         1       22
# 2018-01-04         2       13
# 2018-01-05         2       60
# Total Num of Orders (Invoices) = 1139
# Total Num of Products  = 20641
